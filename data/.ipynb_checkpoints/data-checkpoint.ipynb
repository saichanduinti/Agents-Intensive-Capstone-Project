# %%
import pandas as pd

# Sample dataset
data = {
    "ID": [1, 2, 3, 4, 5, 6],
    "Name": ["Rathiga", "Ramesh", None, "Swastika", "Pratanya", "Lohit"],
    "Age": [25, 30, 22, None, 28, 35],
    "Department": ["HR", "IT", "IT", "Finance", None, "HR"],
    "Salary": [50000, 60000, None, 75000, 62000, 58000],
    "JoiningDate": ["2026-01-15", "2019-03-22", "2021-06-30", "2025-11-01", "2025-08-19", None]
}

df = pd.DataFrame(data)

# Save as Excel
df.to_excel("Fulldataset.csv", index=False)

print("Excel file 'sample_dataset.xlsx' has been created!")
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# ~\anaconda3\envs\AI_MLProject\lib\site-packages\pandas\io\excel\_base.py in __new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     826                 try:
# --> 827                     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#     828                     if engine == "auto":
#
# ~\anaconda3\envs\AI_MLProject\lib\site-packages\pandas\_config\config.py in __call__(self, *args, **kwds)
#     242     def __call__(self, *args, **kwds):
# --> 243         return self.__func__(*args, **kwds)
#     244
#
# ~\anaconda3\envs\AI_MLProject\lib\site-packages\pandas\_config\config.py in _get_option(pat, silent)
#     114 def _get_option(pat: str, silent: bool = False):
# --> 115     key = _get_single_key(pat, silent)
#     116
#
# ...

# %%
import pandas as pd

# Sample dataset
data = {
    "ID": [1, 2, 3, 4, 5, 6],
    "Name": ["Rathiga", "Ramesh", None, "Swastika", "Pratanya", "Lohit"],
    "Age": [25, 30, 22, None, 28, 35],
    "Department": ["HR", "IT", "IT", "Finance", None, "HR"],
    "Salary": [50000, 60000, None, 75000, 62000, 58000],
    "JoiningDate": ["2026-01-15", "2019-03-22", "2021-06-30", "2025-11-01", "2025-08-19", None]
}

df = pd.DataFrame(data)

# Save as CSV
df.to_csv("Fulldataset.csv", index=False)

print("CSV file 'Fulldataset.csv' has been created!")
# Out:
# CSV file 'Fulldataset.csv' has been created!
